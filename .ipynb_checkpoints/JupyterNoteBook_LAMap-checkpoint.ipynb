# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
import numpy as np
from shapely.geometry import Point, Polygon
import folium
import branca

# %%
community_map = gpd.read_file('SHP\LA_SHP\Original_Shp\geo_export_d0097c2a-af0b-498c-ae6f-0f976d91920e.shp')
community_map = community_map.rename(columns={'name':'community'})

df = pd.read_csv('./Data/LA_Crimes.csv')
crs = {'init' : 'epsg:4326'}
df = df.dropna(subset=['LATITUDE'])
df= df[df['LATITUDE'] != 0]

geometry = [Point(xy) for xy in zip(df["LONGITUDE"], df["LATITUDE"])]
geometry[:3]


geo_df = gpd.GeoDataFrame(df, crs = crs, geometry = geometry)
# Out:
# C:\Users\Saajid\anaconda3\envs\geopandas\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
# taken from https://towardsdatascience.com/tagging-a-location-to-a-shapefile-area-using-geopandas-5d74336128bf
geo_df['community'] = ''
for idx in range(community_map.shape[0]):
    #For every lat/long, find if they reside within a community
    try:
        pip = geo_df.within(community_map.loc[idx, 'geometry'])
        if pip.sum() > 0:
            geo_df.loc[pip, 'community']  = community_map.loc[idx, 'community']
    except:
        continue
# Out:
# TopologyException: side location conflict at -118.16418000000017 33.827684999126781

# %%
# geo_df.to_file("LACrime.shp")

# %%
# geo_df = gpd.read_file("SHP\LA_SHP\Summarized_Shp\LACrime.shp")

# %%
# taking group by and then reverting back to data frame to use
# https://technology.amis.nl/data-analytics/convert-groupby-result-on-pandas-data-frame-into-a-data-frame-using-to_frame/
crimebycommunity = geo_df.groupby(['community'])['community'].count().to_frame(name = 'count').reset_index()


crimebycommunity['community'].replace('', np.nan, inplace=True)
crimebycommunity = crimebycommunity.dropna(subset=['community'])


map_and_stats = community_map.merge(crimebycommunity, on="community")

map_and_stats_2 = map_and_stats[['community','geometry','count']]

# %%
# https://vverde.github.io/blob/interactivechoropleth.html

x_map = map_and_stats_2.centroid.x.mean()
y_map = map_and_stats_2.centroid.y.mean()



mymap = folium.Map(location=[y_map, x_map], zoom_start=11,tiles=None)
folium.TileLayer('CartoDB positron',name="Light Map",control=False).add_to(mymap)


myscale = (map_and_stats_2['count'].quantile((0,0.25,0.5,0.9,1))).tolist()
# Out:
# C:\Users\Saajid\AppData\Local\Temp\ipykernel_11968\3853115038.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   x_map = map_and_stats_2.centroid.x.mean()
# C:\Users\Saajid\AppData\Local\Temp\ipykernel_11968\3853115038.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   y_map = map_and_stats_2.centroid.y.mean()

# %%
mymap.choropleth(
geo_data=map_and_stats_2,
name='Choropleth',
data=map_and_stats_2,
columns=['community','count'],
key_on="feature.properties.community",
fill_color='Reds', #https://matplotlib.org/3.5.1/tutorials/colors/colormaps.html          sequential color maps
threshold_scale=myscale,
fill_opacity=0.5,
line_opacity=0.2,
legend_name='Crime Count',
smooth_factor=0
)
# Out:
# C:\Users\Saajid\anaconda3\envs\geopandas\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(

# %%
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d334e95240d647249936689518dfdfbb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d334e95240d647249936689518dfdfbb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d334e95240d647249936689518dfdfbb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d334e95240d647249936689518dfdfbb%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
style_function = lambda x: {'fillColor': '#ffffff',
                            'color':'#000000',
                            'fillOpacity': 0.1,
                            'weight': 0.1}

highlight_function = lambda x: {'fillColor': '#000000',
                                'color':'#000000',
                                'fillOpacity': 0.50,
                                'weight': 0.1}

# %%
CrimeCount = folium.features.GeoJson(
    map_and_stats_2,
    style_function=style_function,
    control=False,
    highlight_function=highlight_function,
    tooltip=folium.features.GeoJsonTooltip(
        fields=['community','count'],
        aliases=['Neighborhood: ','Count of Crimes '],
        style=("background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;")
    )
)
mymap.add_child(CrimeCount)
mymap.keep_in_front(CrimeCount)
folium.LayerControl().add_to(mymap)

# %%
#this map should have the interactivity now
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d334e95240d647249936689518dfdfbb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20background-color%3A%20white%3B%20color%3A%20%23333333%3B%20font-family%3A%20arial%3B%20font-size%3A%2012px%3B%20padding%3A%2010px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20ta ...

# %%
df_airbnb = pd.read_csv('./Data/LA_listings.csv')


airbnb_locations = df_airbnb[['latitude','longitude']]
airbnb_list = airbnb_locations.values.tolist()

# %%
df_airbnb.head()
# Out:
#      id                        listing_url     scrape_id last_scraped  \
# 0  2708  https://www.airbnb.com/rooms/2708  2.020000e+13    12/6/2021
# 1  3021  https://www.airbnb.com/rooms/3021  2.020000e+13    12/7/2021
# 2  5728  https://www.airbnb.com/rooms/5728  2.020000e+13    12/7/2021
# 3  5729  https://www.airbnb.com/rooms/5729  2.020000e+13    12/7/2021
# 4  5843  https://www.airbnb.com/rooms/5843  2.020000e+13    12/6/2021
#
#                                                 name  \
# 0  Runyon Canyon | Beau Furn Mirror Mini-Suite Fi...
# 1    Hollywood Hills Zen Modern style Apt/Guesthouse
# 2    Tiny Home in Artistic Oasis near Venice and LAX
# 3     Zen Room with Floating Bed near Venice and LAX
# 4  Artist Oasis near Venice Beach w/ Beautiful Ga...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...     3008
# 1  https://a0.muscache.com/pictures/5147dcd2-efad...     3415
# 2  https://a0.muscache.com/pictures/7a29d275-f293...     9171
# 3  https://a0.muscache.com/pictures/f48e3ea8-2075...     9171
# 4  https://a0.muscache.com/pictures/25d657aa-2529...     9171
#
#                                  host_url host_name host_since  ...  \
# 0  https://www.airbnb.com/users/show/3008     Chas.  9/16/2008  ...
# 1  https://www.airbnb.com/users/show/3415   Nataraj  10/2/2008  ...
# 2  https://www.airbnb.com/users/show/9171     Sanni   3/5/2009  ...
# 3  https://www.airbnb.com/users/show/9171     Sanni   3/5/2009  ...
# 4  https://www.airbnb.com/users/show/9171     Sanni   3/5/2009  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.97                   5.00                4.85
# 1                        4.30                   4.64                4.00
# 2                        4.92                   4.79                4.70
# 3                        4.89                   4.76                4.71
# 4                        4.92                   4.75                4.53
#
#         license instant_bookable calculated_host_listings_count  \
# 0           NaN                t                              3
# 1           NaN                f                              4
# 2  HSR19-002149                f                              4
# 3  HSR19-002149                f                              4
# 4  HSR19-002149                f                              4
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            3
# 1                                            3
# 2                                            3
# 3                                            3
# 4                                            3
#
#   calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                           0               0.69
# 1                                           0               0.23
# 2                                           0               4.25
# 3                                           0               4.48
# 4                                           0               1.00
#
# [5 rows x 72 columns]

# %%
def popup_html(row_num, df_airbnb):
    i = row_num
    name=df_airbnb['name'].iloc[i]
    price=df_airbnb['price'].iloc[i]
    roomtype=df_airbnb['room_type'].iloc[i]
    neighbourhood_cleansed = df_airbnb['neighbourhood_cleansed'].iloc[i]


    left_col_color = "#19a7bd"
    right_col_color = "#f2f0d3"

    html = """<!DOCTYPE html>
<html>

<head>
<h4 style="margin-bottom:10"; width="200px">{}</h4>""".format(name) + """

</head>
    <table style="height: 20px; width: 200px; border:1px solid black">
<tbody>
<tr style = "border:1px solid black">
<td style = "border:1px solid black">Price Per Night:</td>
<td style = "border:1px solid black">&nbsp; {}</td>""" .format(price) + """
</tr>

<tr style = "border:1px solid black">
<td style = "border:1px solid black">Room Type:</td>
<td style = "border:1px solid black">&nbsp; {}</td>""" .format(roomtype) + """
</tr>

</tbody>
</table>
</html>
"""
    return html

# %%
# set price to 200 for testing
price = 100
df_airbnb_price_filtered = df_airbnb[df_airbnb.price==price]
rows = len(df_airbnb_price_filtered)
#https://georgetsilva.github.io/posts/mapping-points-with-folium/
#https://towardsdatascience.com/folium-map-how-to-create-a-table-style-pop-up-with-html-code-76903706b88a
for point in range(0,rows):
    i = point
    html = popup_html(i,df_airbnb_price_filtered)
    iframe = branca.element.IFrame(html=html,width=200,height=200)
    popup = folium.Popup(folium.Html(html, script=True), max_width=500)
    folium.Marker(airbnb_list[point], popup).add_to(mymap)
# Out:
# Hollywood Hills
# Echo Park
# Atwater Village
# Hollywood
# Hollywood
# Venice
# Westwood
# Atwater Village
# Baldwin Hills/Crenshaw
# Sunland
# Beverly Grove
# Hollywood Hills
# Beverlywood
# Carthay
# Venice
# Hollywood Hills
# Silver Lake
# Del Rey
# Beverly Grove
# Venice
# Venice
# Valley Village
# Echo Park
# North Hollywood
# Studio City
# Sherman Oaks
# Sherman Oaks
# Mid-City
# Venice
# Echo Park
# Glassell Park
# West Los Angeles
# Silver Lake
# Venice
# Reseda
# West Los Angeles
# West Los Angeles
# Venice
# Hancock Park
# Beverly Grove
# Studio City
# Hollywood Hills
# Koreatown
# Hollywood
# Woodland Hills
# Fairfax
# Pico-Robertson
# Silver Lake
# Carthay
# University Park
# Koreatown
# Mount Washington
# Sawtelle
# Sawtelle
# Playa Vista
# Koreatown
# Larchmont
# Hollywood Hills West
# Brentwood
# Sawtelle
# Hollywood
# Mid-Wilshire
# Studio City
# Tarzana
# Pico-Robertson
# Venice
# Venice
# Hollywood
# Hollywood
# Palms
# Jefferson Park
# Hollywood
# Elysian Valley
# Brentwood
# Silver Lake
# Hollywood
# Hollywood
# Hollywood Hills
# East Hollywood
# North Hollywood
# North Hollywood
# Sherman Oaks
# Van Nuys
# Koreatown
# Silver Lake
# Westwood
# Hollywood
# Sawtelle
# Venice
# Del Rey
# North Hollywood
# Woodland Hills
# East Hollywood
# Downtown
# Rancho Park
# Westwood
# Hollywood Hills
# Larchmont
# Hollywood
# Los Feliz
# Echo Park
# West Hills
# Pacific Palisades
# Koreatown
# Hollywood
# Venice
# North Hollywood
# Mar Vista
# Beverly Grove
# Valley Village
# Mar Vista
# Los Feliz
# Beverly Grove
# Westlake
# Adams-Normandie
# Windsor Square
# Elysian Valley
# Highland Park
# Vermont Square
# North Hills
# Del Rey
# Venice
# Mar Vista
# Mid-City
# Valley Glen
# Highland Park
# Hollywood
# Sherman Oaks
# North Hollywood
# Los Feliz
# Westlake
# East Hollywood
# Palms
# Downtown
# Silver Lake
# Hollywood
# Koreatown
# Larchmont
# Sawtelle
# Pico-Robertson
# Echo Park
# Los Feliz
# Koreatown
# Hollywood
# Montecito Heights
# Hyde Park
# Mount Washington
# Lake Balboa
# Hollywood
# Venice
# Hollywood Hills West
# Palms
# North Hollywood
# West Adams
# Silver Lake
# Highland Park
# Pico-Union
# Leimert Park
# Del Rey
# Beverly Grove
# Studio City
# Hollywood Hills West
# Hollywood
# Hollywood Hills
# Hollywood
# Pico-Robertson
# Echo Park
# Century City
# Sun Valley
# Palms
# Venice
# Hollywood
# Downtown
# Downtown
# Beverly Grove
# Highland Park
# Hollywood
# Hollywood
# San Pedro
# Westwood
# Downtown
# Los Feliz
# Los Feliz
# Playa del Rey
# Baldwin Hills/Crenshaw
# Los Feliz
# Boyle Heights
# Hollywood
# Valley Glen
# Silver Lake
# Venice
# Van Nuys
# Hollywood
# Westlake
# Exposition Park
# Hollywood Hills
# Palms
# Pico-Robertson
# Hollywood
# Brentwood
# Mid-Wilshire
# North Hollywood
# Hollywood Hills
# Sawtelle
# Hollywood
# Downtown
# Boyle Heights
# Studio City
# North Hollywood
# Venice
# Silver Lake
# Larchmont
# Downtown
# Beverly Grove
# Venice
# Mid-City
# Rancho Park
# Downtown
# Sherman Oaks
# Wilmington
# Winnetka
# Studio City
# Brentwood
# Studio City
# Downtown
# Hollywood
# Koreatown
# Downtown
# East Hollywood
# Exposition Park
# Westlake
# North Hollywood
# Mid-Wilshire
# Studio City
# Westlake
# Downtown
# Hollywood
# Mid-City
# Harvard Heights
# Venice
# Venice
# Koreatown
# Downtown
# Sawtelle
# Vermont Square
# North Hollywood
# Hyde Park
# Pico-Robertson
# Pacoima
# Baldwin Hills/Crenshaw
# Van Nuys
# Hollywood Hills
# Mar Vista
# Mar Vista
# Sun Valley
# Beverly Grove
# Brentwood
# Echo Park
# Venice
# Valley Glen
# East Hollywood
# Hancock Park
# Koreatown
# Westchester
# Westchester
# Fairfax
# Palms
# West Adams
# Koreatown
# Highland Park
# East Hollywood
# Pico-Robertson
# Adams-Normandie
# Mount Washington
# Venice
# Del Rey
# Echo Park
# Downtown
# Sawtelle
# Woodland Hills
# North Hollywood
# Hollywood
# North Hollywood
# Westlake
# Venice
# Sherman Oaks
# Beverly Grove
# Sawtelle
# Venice
# Valley Village
# Sherman Oaks
# Downtown
# Hyde Park
# Sawtelle
# San Pedro
# Echo Park
# Del Rey
# Westwood
# Venice
# Koreatown
# Mar Vista
# Highland Park
# Valley Glen
# Del Rey
# Toluca Lake
# Mid-City
# Westwood
# Venice
# Sun Valley
# Canoga Park
# Mission Hills
# West Hills
# Van Nuys
# Downtown
# Hollywood
# Pico-Union
# Hollywood Hills
# North Hollywood
# Hollywood Hills
# Chatsworth
# Beverly Grove
# Panorama City
# Hollywood Hills West
# Echo Park
# Beverly Grove
# Valley Village
# Silver Lake
# Echo Park
# Hollywood Hills West
# Venice
# San Pedro
# San Pedro
# San Pedro
# Venice
# Venice
# Venice
# Mar Vista
# Koreatown
# Hollywood Hills
# Carthay
# Studio City
# Montecito Heights
# Mid-Wilshire
# Valley Glen
# Pico-Robertson
# Silver Lake
# West Hills
# Venice
# Encino
# Studio City
# Beverly Grove
# Mar Vista
# Westchester
# Jefferson Park
# Playa Vista
# Koreatown
# Hollywood
# Mid-Wilshire
# Hollywood
# Mid-Wilshire
# Hollywood
# Mar Vista
# Sawtelle
# Pico-Union
# Highland Park
# Mid-Wilshire
# Mid-Wilshire
# Woodland Hills
# Hollywood
# Mid-City
# Mid-Wilshire
# Jefferson Park
# Valley Village
# Koreatown
# Echo Park
# Mid-Wilshire
# Northridge
# Panorama City
# University Park
# University Park
# Mid-Wilshire
# Mid-Wilshire
# Hollywood
# Downtown
# Westchester
# Sylmar
# Highland Park
# Westwood
# Palms
# Venice
# Mid-Wilshire
# Downtown
# Mid-Wilshire
# Mar Vista
# Mid-Wilshire
# Playa Vista
# Palms
# Beverly Grove
# Koreatown
# Koreatown
# Koreatown
# Mar Vista
# Glassell Park
# Venice
# Hollywood
# Westchester
# Gramercy Park
# Westlake
# Sherman Oaks
# Hollywood Hills
# Mid-Wilshire
# Canoga Park
# Venice
# Boyle Heights
# Gramercy Park
# Mid-City
# Hollywood
# North Hollywood
# Studio City
# Hyde Park
# Mid-City
# Venice
# Westchester
# Mid-City
# Downtown
# Downtown
# Mid-City
# Reseda
# Exposition Park
# Westchester
# Arlington Heights
# Mid-City
# Westchester
# Koreatown
# Downtown
# Woodland Hills
# Canoga Park
# Mar Vista
# Pico-Union
# Reseda
# Sun Valley
# Mission Hills
# Silver Lake
# Westlake
# Hollywood Hills
# Studio City
# Jefferson Park
# Jefferson Park
# Jefferson Park
# Jefferson Park
# Jefferson Park
# Jefferson Park
# Vermont Knolls
# Brentwood
# Mid-Wilshire
# Venice
# Venice

# %%
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d334e95240d647249936689518dfdfbb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20background-color%3A%20white%3B%20color%3A%20%23333333%3B%20font-family%3A%20arial%3B%20font-size%3A%2012px%3B%20padding%3A%2010px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20ta ...

# %%
# if you want to save html locally
# mymap.save("index_LA.html")
